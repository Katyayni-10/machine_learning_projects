# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Mall_Customers.csv")

# %%
x=df[['Annual Income (k$)','Spending Score (1-100)']]

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=x['Annual Income (k$)'],y=x['Spending Score (1-100)'],hue=df['Genre'])
plt.show()

# %%
kmeans=KMeans(n_clusters=5,random_state=42)

# %%
kmeans.fit(x_scaled)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=x['Annual Income (k$)'],y=x['Spending Score (1-100)'],hue=df['Age'])
plt.show()

# %%
centroids_scaled = kmeans.cluster_centers_
centroids = scaler.inverse_transform(centroids_scaled)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['Annual Income (k$)'], y=df['Spending Score (1-100)'], hue=df['Age'], palette='Set1', s=60)
plt.scatter(centroids[:, 0],centroids[:, 1],c='black',marker='X',s=200,label='Centroids')
plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
plt.title("K-Means Customer Segmentation")
plt.legend()
plt.show()

# %%
import pickle
pickle.dump(kmeans, open('kmeans_model.pkl', 'wb'))
pickle.dump(scaler, open('scaler.pkl', 'wb'))
print('Model saved')
# Out:
# Model saved
